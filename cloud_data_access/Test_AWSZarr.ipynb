# %% [markdown]
# # AWS Zarr Data Tests

# %% [markdown]
# ### Import Modules

# %%
import s3fs
import numpy as np
import xarray as xr
import fsspec
import zarr
import timeit
import matplotlib.pyplot as plt
from dask.distributed import Client

# %% [markdown]
# ### Dataset URL
# <br/>
# We use this URL to reference the MUR 1-km L4 dataset on the AWS Open Registry.

# %%
URL = 's3://mur-sst/zarr'

# %% [markdown]
# ## Setup for Global Tests

# %% [markdown]
# ### Open MUR Dataset
# <br/>
# Open the remote dataset from its S3 endpoint. The dataset is pre-consolidated, meaning the metadata is stored in a single, optimized resource. We can take advantage of this by declaring 'consolidated=True' which uses that resource to reduce the number of read operations when opening the data.

# %%
start_time = timeit.default_timer()

mur_global = xr.open_zarr(
    fsspec.get_mapper(URL, anon=True), 
    consolidated=True, 
).chunk({"time": 30, "lat": 100, "lon": 100})

elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# 844.6709574030001

# %%
mur_global
# Out:
# <xarray.Dataset>
# Dimensions:           (lat: 17999, lon: 36000, time: 6443)
# Coordinates:
#   * lat               (lat) float32 -89.99 -89.98 -89.97 ... 89.97 89.98 89.99
#   * lon               (lon) float32 -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
#   * time              (time) datetime64[ns] 2002-06-01T09:00:00 ... 2020-01-2...
# Data variables:
#     analysed_sst      (time, lat, lon) float32 dask.array<chunksize=(30, 100, 100), meta=np.ndarray>
#     analysis_error    (time, lat, lon) float32 dask.array<chunksize=(30, 100, 100), meta=np.ndarray>
#     mask              (time, lat, lon) int8 dask.array<chunksize=(30, 100, 100), meta=np.ndarray>
#     sea_ice_fraction  (time, lat, lon) float32 dask.array<chunksize=(30, 100, 100), meta=np.ndarray>
# Attributes: (12/47)
#     Conventions:                CF-1.7
#     Metadata_Conventions:       Unidata Observation Dataset v1.0
#     acknowledgment:             Please acknowledge the use of these data with...
#     cdm_data_type:              grid
#     comment:                    MUR = "Multi-scale Ultra-high Resolution"
#     creator_email:              ghrsst@podaac.jpl.nasa.gov
#     ...                         ...
#     summary:                    A merged, multi-sensor L4 Foundation SST anal...
#     time_coverage_end:          20200116T210000Z
#     time_coverage_start:        20200115T210000Z
#     title:                      Daily MUR SST, Final product
#     uuid:                       27665bc0-d5fc-11e1-9b23-0800200c9a66
#     westernmost_longitude:      -180.0

# %% [markdown]
# ### Add in NAN Values for Land to MUR Data
# <br/>
# We use the mask dimension to replace temperature values from land observations with NaN so that they are not factored in to our calculations. The mask variable has a value for each coordinate pair representing which surface the temperature was collected from (land, open-sea, ice, etc.).

# %%
mur_global_sst = mur_global['analysed_sst'].where(mur_global.mask == 1)

# %% [markdown]
# ### Convert Temperatures to Celsius
# <br/>
# The dataset is stored with temperatures measured in Kelvin. This converts it to Celsius for ease of understanding and analysis.

# %%
mur_global_sst = mur_global_sst - 273.15

# %% [markdown]
# ### Find Daily Average Temperature for Time Series

# %%
mur_global_sst_mean_ts = mur_global_sst.mean(['lat', 'lon'])

# %% [markdown]
# ### Find Average Temperature for Each Coordinate Pair for Spatial Plot

# %%
mur_global_sst_mean_sp = mur_global_sst.mean(['time'])

# %% [markdown]
# ## Global Tests

# %% [markdown]
# ### Global SST Averaged Time Series

# %%
start_time = timeit.default_timer()

mur_global_sst_mean_ts.plot()

elapsed = timeit.default_timer() - start_time
print(elapsed)

# %% [markdown]
# ### Global SST Averaged Spatial Plot

# %%
start_time = timeit.default_timer()

mur_global_sst_mean_sp.plot()

elapsed = timeit.default_timer() - start_time
print(elapsed)

# %% [markdown]
# ## Setup for Regional Tests

# %% [markdown]
# ### Period and Region of Interest

# %%
start_date = "2019-08-01"
end_date = "2020-1-20"

minlat = 18
maxlat = 25
minlon = -160
maxlon = -150

# %% [markdown]
# ### Open MUR Dataset
# <br/>
# Open the remote dataset from its S3 endpoint. The dataset is pre-consolidated, meaning the metadata is stored in a single, optimized resource. We can take advantage of this by declaring 'consolidated=True' which uses that resource to reduce the number of read operations when opening the data.

# %%
start_time = timeit.default_timer()


mur_global = xr.open_zarr(fsspec.get_mapper(URL, anon=True), consolidated=True)

variables=[
    'analysed_sst', 
    'mask'
]

mur_hawaii = mur_global[variables].sel(
    time=slice(start_date, end_date),
    lat=slice(minlat, maxlat), 
    lon=slice(minlon, maxlon),
).chunk({"time": 30, "lat": 100, "lon": 100})


elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# 17.777727263000088

# %%
mur_hawaii
# Out:
# <xarray.Dataset>
# Dimensions:       (lat: 701, lon: 1001, time: 173)
# Coordinates:
#   * lat           (lat) float32 18.0 18.01 18.02 18.03 ... 24.98 24.99 25.0
#   * lon           (lon) float32 -160.0 -160.0 -160.0 ... -150.0 -150.0 -150.0
#   * time          (time) datetime64[ns] 2019-08-01T09:00:00 ... 2020-01-20T09...
# Data variables:
#     analysed_sst  (time, lat, lon) float32 dask.array<chunksize=(30, 100, 100), meta=np.ndarray>
#     mask          (time, lat, lon) int8 dask.array<chunksize=(30, 100, 100), meta=np.ndarray>
# Attributes: (12/47)
#     Conventions:                CF-1.7
#     Metadata_Conventions:       Unidata Observation Dataset v1.0
#     acknowledgment:             Please acknowledge the use of these data with...
#     cdm_data_type:              grid
#     comment:                    MUR = "Multi-scale Ultra-high Resolution"
#     creator_email:              ghrsst@podaac.jpl.nasa.gov
#     ...                         ...
#     summary:                    A merged, multi-sensor L4 Foundation SST anal...
#     time_coverage_end:          20200116T210000Z
#     time_coverage_start:        20200115T210000Z
#     title:                      Daily MUR SST, Final product
#     uuid:                       27665bc0-d5fc-11e1-9b23-0800200c9a66
#     westernmost_longitude:      -180.0

# %% [markdown]
# ### Add in NAN Values for Land to MUR Data
# <br/>
# We use the mask dimension to replace temperature values from land observations with NaN so that they are not factored in to our calculations. The mask variable has a value for each coordinate pair representing which surface the temperature was collected from (land, open-sea, ice, etc.).

# %%
mur_hawaii_sst = mur_hawaii['analysed_sst'].where(mur_hawaii.mask == 1)

# %% [markdown]
# ### Convert Temperatures to Celsius
# <br/>
# The dataset is stored with temperatures measured in Kelvin. This converts it to Celsius for ease of understanding and analysis.

# %%
mur_hawaii_sst = mur_hawaii_sst - 273.15

# %%
mur_hawaii_sst

# %% [markdown]
# ### Open MUR Climatology for Hawaii

# %%
mur_clim = xr.open_dataarray(
    "../data/MURClimatology.nc", 
    chunks={"time": 30, "lat": 100, "lon": 100}
)

# %%
mur_clim
# Out:
# <xarray.DataArray 'sstclim' (time: 366, lat: 701, lon: 1001)>
# dask.array<open_dataset-58403cc5cb4b2491ab84b4c0a1048a18sstclim, shape=(366, 701, 1001), dtype=float32, chunksize=(30, 100, 100), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float32 -160.0 -160.0 -160.0 -160.0 ... -150.0 -150.0 -150.0
#   * lat      (lat) float32 18.0 18.01 18.02 18.03 ... 24.97 24.98 24.99 25.0
#   * time     (time) datetime64[ns] 2004-01-01T09:00:00 ... 2004-12-31T09:00:00
# Attributes:
#     description:  Hawaii Climatology from 2002-2015.
#     start_date:   01/01
#     end_date:     12/31
#     units:        degC

# %% [markdown]
# ### Drop the Leap Day

# %%
mur_clim = mur_clim.where(mur_clim["time"] != np.datetime64('2004-02-29T09:00:00', 'ns'), drop=True)

# %% [markdown]
# ### Create Subset

# %%
mur_clim_jan = mur_clim[0:20]

# %%
mur_clim_subset = mur_clim[212:]

# %%
mur_clim_subset = xr.concat([mur_clim_subset, mur_clim_jan], dim="time")

# %%
mur_clim_subset = mur_clim_subset.assign_coords({"time": mur_hawaii_sst["time"]})

# %%
mur_clim_subset
# Out:
# <xarray.DataArray 'sstclim' (time: 173, lat: 701, lon: 1001)>
# dask.array<concatenate, shape=(173, 701, 1001), dtype=float32, chunksize=(30, 100, 100), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float32 -160.0 -160.0 -160.0 -160.0 ... -150.0 -150.0 -150.0
#   * lat      (lat) float32 18.0 18.01 18.02 18.03 ... 24.97 24.98 24.99 25.0
#   * time     (time) datetime64[ns] 2019-08-01T09:00:00 ... 2020-01-20T09:00:00
# Attributes:
#     description:  Hawaii Climatology from 2002-2015.
#     start_date:   01/01
#     end_date:     12/31
#     units:        degC

# %% [markdown]
# ### Create SST Anomaly Dataset

# %%
sst_anomaly = mur_hawaii_sst - mur_clim_subset

# %%
sst_anomaly
# Out:
# <xarray.DataArray (time: 173, lat: 701, lon: 1001)>
# dask.array<sub, shape=(173, 701, 1001), dtype=float32, chunksize=(27, 100, 100), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float32 18.0 18.01 18.02 18.03 ... 24.97 24.98 24.99 25.0
#   * lon      (lon) float32 -160.0 -160.0 -160.0 -160.0 ... -150.0 -150.0 -150.0
#   * time     (time) datetime64[ns] 2019-08-01T09:00:00 ... 2020-01-20T09:00:00

# %% [markdown]
# ### Find Daily Average SST Anomaly for Time Series

# %%
sst_anomaly_mean_ts = sst_anomaly.mean(['lat', 'lon'])

# %%
sst_anomaly_mean_ts
# Out:
# <xarray.DataArray (time: 173)>
# dask.array<mean_agg-aggregate, shape=(173,), dtype=float32, chunksize=(27,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2019-08-01T09:00:00 ... 2020-01-20T09:00:00

# %% [markdown]
# ### Find Average SST Anomaly for Each Coordinate Pair for Spatial Plot

# %%
sst_anomaly_mean_sp = sst_anomaly.mean(['time'])

# %%
sst_anomaly_mean_sp
# Out:
# <xarray.DataArray (lat: 701, lon: 1001)>
# dask.array<mean_agg-aggregate, shape=(701, 1001), dtype=float32, chunksize=(100, 100), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float32 18.0 18.01 18.02 18.03 ... 24.97 24.98 24.99 25.0
#   * lon      (lon) float32 -160.0 -160.0 -160.0 -160.0 ... -150.0 -150.0 -150.0

# %% [markdown]
# ## Regional Tests

# %% [markdown]
# ### Regional SST Anomaly Averaged Time Series, August 1st, 2019 - January 20th, 2020

# %%
start_time = timeit.default_timer()

sst_anomaly_mean_ts.plot()

elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-21e2691d23d5> in <module>
#       1 start_time = timeit.default_timer()
#       2
# ----> 3 sst_anomaly_mean_ts.plot()
#       4
#       5 elapsed = timeit.default_timer() - start_time
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/plot/plot.py in __call__(self, **kwargs)
#     450
#     451     def __call__(self, **kwargs):
# --> 452         return plot(self._da, **kwargs)
#     453
#     454     # we can't use functools.wraps here since that also modifies the name / qualname
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/plot/plot.py in plot(darray, row, col, col_wrap, ax, hue, rtol, subplot_kws, **kwargs)
#     164     xarray.DataArray.squeeze
#     165     """
# --> 166     darray = darray.squeeze().compute()
#     167
#     168     plot_dims = set(darray.dims)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py in compute(self, **kwargs)
#     909         """
#     910         new = self.copy(deep=False)
# --> 911         return new.load(**kwargs)
#     912
#     913     def persist(self, **kwargs) -> "DataArray":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py in load(self, **kwargs)
#     883         dask.compute
#     884         """
# --> 885         ds = self._to_temp_dataset().load(**kwargs)
#     886         new = self._from_temp_dataset(ds)
#     887         self._variable = new._variable
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/core/dataset.py in load(self, **kwargs)
#     848
#     849             # evaluate all the dask arrays simultaneously
# --> 850             evaluated_data = da.compute(*lazy_data.values(), **kwargs)
#     851
#     852             for k, data in zip(lazy_data, evaluated_data):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     450         postcomputes.append(x.__dask_postcompute__())
#     451
# --> 452     results = schedule(dsk, keys, **kwargs)
#     453     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     454
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      74                 pools[thread][num_workers] = pool
#      75
# ---> 76     results = get_async(
#      77         pool.apply_async,
#      78         len(pool._pool),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dask/local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     473             # Main loop, wait on tasks to finish, insert new ones
#     474             while state["waiting"] or state["ready"] or state["running"]:
# --> 475                 key, res_info, failed = queue_get(queue)
#     476                 if failed:
#     477                     exc, tb = loads(res_info)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dask/local.py in queue_get(q)
#     131
#     132     def queue_get(q):
# --> 133         return q.get()
#     134
#     135
#
# ~/opt/anaconda3/lib/python3.8/queue.py in get(self, block, timeout)
#     168             elif timeout is None:
#     169                 while not self._qsize():
# --> 170                     self.not_empty.wait()
#     171             elif timeout < 0:
#     172                 raise ValueError("'timeout' must be a non-negative number")
#
# ~/opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Regional SST Anomaly Averaged Spatial Plot, August 1st, 2019 - January 20th, 2020

# %%
start_time = timeit.default_timer()

sst_anomaly_mean_sp.plot()

elapsed = timeit.default_timer() - start_time
print(elapsed)
