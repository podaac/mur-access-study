# %% [markdown]
# # AWS Zarr Eosdis Store Data Tests

# %% [markdown]
# **Goal**
# <br/>
# To open the MUR 1-km dataset stored in the PO.DAAC Archive using the zarr-easdis-store package in conjunction with the MUR Climatology dataset (created by Mike Chin and cleaned in the notebook 'CleaningMURClimatologyData.ipynb') to create a Sea Surface Temperature (SST) anomaly dataset for use in testing runtimes on dataset loading and plotting applications.

# %% [markdown]
# **Run Location**
# <br/>
# This notebook was run on an AWS EC2 t3.medium instance. It also did not work on a t3.small instance. Memory or disk space are not the issue with this code.

# %% [markdown]
# **Dataset**
# <br/>
# MUR 1-km L4 SST netCDF4 On-Premise https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/

# %% [markdown]
# ### Import Modules

# %%
# %matplotlib inline
import sys
from eosdis_store import EosdisStore

import s3fs
import numpy as np
import xarray as xr
import fsspec
import zarr
import timeit
import matplotlib.pyplot as plt
from dask.distributed import Client, performance_report

# %% [markdown]
# ### Save Access URL

# %%
BASEURL = 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/'

# %% [markdown]
# ## Setup for Regional Tests

# %% [markdown]
# ### Period and Region of Interest

# %%
start_date = "2019-08-01"
end_date = "2020-01-21"

minlat = 18
maxlat = 23
minlon = -160
maxlon = -154

# %% [markdown]
# ### Create Labels for Necessary Days

# %%
dates = np.arange(start_date, end_date, dtype='datetime64[D]')
dates
# Out:
# array(['2019-08-01', '2019-08-02', '2019-08-03', '2019-08-04',
#        '2019-08-05', '2019-08-06', '2019-08-07', '2019-08-08',
#        '2019-08-09', '2019-08-10', '2019-08-11', '2019-08-12',
#        '2019-08-13', '2019-08-14', '2019-08-15', '2019-08-16',
#        '2019-08-17', '2019-08-18', '2019-08-19', '2019-08-20',
#        '2019-08-21', '2019-08-22', '2019-08-23', '2019-08-24',
#        '2019-08-25', '2019-08-26', '2019-08-27', '2019-08-28',
#        '2019-08-29', '2019-08-30', '2019-08-31', '2019-09-01',
#        '2019-09-02', '2019-09-03', '2019-09-04', '2019-09-05',
#        '2019-09-06', '2019-09-07', '2019-09-08', '2019-09-09',
#        '2019-09-10', '2019-09-11', '2019-09-12', '2019-09-13',
#        '2019-09-14', '2019-09-15', '2019-09-16', '2019-09-17',
#        '2019-09-18', '2019-09-19', '2019-09-20', '2019-09-21',
#        '2019-09-22', '2019-09-23', '2019-09-24', '2019-09-25',
#        '2019-09-26', '2019-09-27', '2019-09-28', '2019-09-29',
#        '2019-09-30', '2019-10-01', '2019-10-02', '2019-10-03',
#        '2019-10-04', '2019-10-05', '2019-10-06', '2019-10-07',
#        '2019-10-08', '2019-10-09', '2019-10-10', '2019-10-11',
#        '2019-10-12', '2019-10-13', '2019-10-14', '2019-10-15',
#        '2019-10-16', '2019-10-17', '2019-10-18', '2019-10-19',
#        '2019-10-20', '2019-10-21', '2019-10-22', '2019-10-23',
#        '2019-10-24', '2019-10-25', '2019-10-26', '2019-10-27',
#        '2019-10-28', '2019-10-29', '2019-10-30', '2019-10-31',
#        '2019-11-01', '2019-11-02', '2019-11-03', '2019-11-04',
#        '2019-11-05', '2019-11-06', '2019-11-07', '2019-11-08',
#        '2019-11-09', '2019-11-10', '2019-11-11', '2019-11-12',
#        '2019-11-13', '2019-11-14', '2019-11-15', '2019-11-16',
#        '2019-11-17', '2019-11-18', '2019-11-19', '2019-11-20',
#        '2019-11-21', '2019-11-22', '2019-11-23', '2019-11-24',
#        '2019-11-25', '2019-11-26', '2019-11-27', '2019-11-28',
#        '2019-11-29', '2019-11-30', '2019-12-01', '2019-12-02',
#        '2019-12-03', '2019-12-04', '2019-12-05', '2019-12-06',
#        '2019-12-07', '2019-12-08', '2019-12-09', '2019-12-10',
#        '2019-12-11', '2019-12-12', '2019-12-13', '2019-12-14',
#        '2019-12-15', '2019-12-16', '2019-12-17', '2019-12-18',
#        '2019-12-19', '2019-12-20', '2019-12-21', '2019-12-22',
#        '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#        '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#        '2019-12-31', '2020-01-01', '2020-01-02', '2020-01-03',
#        '2020-01-04', '2020-01-05', '2020-01-06', '2020-01-07',
#        '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-11',
#        '2020-01-12', '2020-01-13', '2020-01-14', '2020-01-15',
#        '2020-01-16', '2020-01-17', '2020-01-18', '2020-01-19',
#        '2020-01-20'], dtype='datetime64[D]')

# %% [markdown]
# ### Create URLs for Accessing Data

# %%
urls = []

for day in dates:
    urls.append(BASEURL + str(str(day).replace('-', '')) + '090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc')
    
urls
# Out:
# ['https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190801090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190802090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190803090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190804090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190805090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190806090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190807090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190808090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190809090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190810090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190811090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190812090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190813090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190814090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190815090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190816090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190817090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190818090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190819090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190820090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190821090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190822090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190823090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190824090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190825090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190826090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190827090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190828090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190829090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190830090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190831090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190901090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190902090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190903090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190904090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190905090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190906090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190907090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190908090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190909090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190910090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190911090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190912090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190913090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190914090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190915090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190916090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190917090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190918090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190919090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190920090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190921090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190922090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190923090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190924090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190925090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190926090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190927090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190928090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190929090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20190930090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191001090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191002090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191003090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191004090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191005090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191006090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191007090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191008090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191009090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191010090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191011090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191012090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191013090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191014090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191015090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191016090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191017090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191018090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191019090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191020090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191021090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191022090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191023090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191024090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191025090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191026090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191027090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191028090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191029090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191030090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191031090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191101090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191102090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191103090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191104090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191105090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191106090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191107090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191108090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191109090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191110090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191111090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191112090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191113090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191114090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191115090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191116090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191117090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191118090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191119090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191120090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191121090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191122090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191123090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191124090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191125090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191126090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191127090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191128090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191129090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191130090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191201090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191202090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191203090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191204090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191205090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191206090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191207090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191208090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191209090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191210090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191211090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191212090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191213090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191214090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191215090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191216090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191217090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191218090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191219090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191220090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191221090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191222090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191223090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191224090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191225090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191226090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191227090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191228090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191229090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191230090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20191231090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200101090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200102090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200103090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200104090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200105090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200106090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200107090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200108090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200109090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200110090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200111090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200112090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200113090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200114090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200115090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200116090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200117090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200118090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200119090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#  'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20200120090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc']

# %% [markdown]
# ### Open MUR Dataset

# %%
start_time = timeit.default_timer()

variables=[
    'analysed_sst', 
    'mask'
]

def subset(ds):
    subset_ds = ds[variables].sel(
        lat=slice(minlat, maxlat),
        lon=slice(minlon, maxlon)
    )
    return subset_ds

mur_hawaii = xr.open_mfdataset(
    paths=[EosdisStore(f) for f in urls],
    preprocess=subset,
    combine='by_coords',
    consolidated=False,
    mask_and_scale=True,
#     decode_cf=True,
#     cache=False,
#     parallel=True,
    engine='zarr'
).chunk({"time": 30, "lat": 100, "lon": 100})

mur_hawaii.load()   # Uncomment if you want to load the dataset into memory now

elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-c9e4ac9a2a5a> in <module>
#      25 ).chunk({"time": 30, "lat": 100, "lon": 100})
#      26
# ---> 27 mur_hawaii.load()   # Uncomment if you want to load the dataset into memory now
#      28
#      29 elapsed = timeit.default_timer() - start_time
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/dataset.py in load(self, **kwargs)
#     863
#     864             # evaluate all the dask arrays simultaneously
# --> 865             evaluated_data = da.compute(*lazy_data.values(), **kwargs)
#     866
#     867             for k, data in zip(lazy_data, evaluated_data):
#
# ~/miniconda3/lib/python3.9/site-packages/dask/base.py in compute(*args, **kwargs)
#     566         postcomputes.append(x.__dask_postcompute__())
#     567
# --> 568     results = schedule(dsk, keys, **kwargs)
#     569     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     570
#
# ~/miniconda3/lib/python3.9/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      77             pool = MultiprocessingPoolExecutor(pool)
#      78
# ---> 79     results = get_async(
#      80         pool.submit,
#      81         pool._max_workers,
#
# ~/miniconda3/lib/python3.9/site-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     512                             _execute_task(task, data)  # Re-execute locally
#     513                         else:
# --> 514                             raise_exception(exc, tb)
#     515                     res, worker_id = loads(res_info)
#     516                     state["cache"][key] = res
#
# ~/miniconda3/lib/python3.9/site-packages/dask/local.py in reraise(exc, tb)
#     323     if exc.__traceback__ is not tb:
#     324         raise exc.with_traceback(tb)
# --> 325     raise exc
#     326
#     327
#
# ~/miniconda3/lib/python3.9/site-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     221     try:
#     222         task, data = loads(task_info)
# --> 223         result = _execute_task(task, data)
#     224         id = get_id()
#     225         result = dumps((result, id))
#
# ~/miniconda3/lib/python3.9/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~/miniconda3/lib/python3.9/site-packages/dask/array/core.py in getter(a, b, asarray, lock)
#     102         # `is_arraylike` evaluates to `True` in that case.
#     103         if asarray and (not is_arraylike(c) or isinstance(c, np.matrix)):
# --> 104             c = np.asarray(c)
#     105     finally:
#     106         if lock:
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     352
#     353     def __array__(self, dtype=None):
# --> 354         return np.asarray(self.array, dtype=dtype)
#     355
#     356     def __getitem__(self, key):
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     516
#     517     def __array__(self, dtype=None):
# --> 518         return np.asarray(self.array, dtype=dtype)
#     519
#     520     def __getitem__(self, key):
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     417     def __array__(self, dtype=None):
#     418         array = as_indexable(self.array)
# --> 419         return np.asarray(array[self.key], dtype=None)
#     420
#     421     def transpose(self, order):
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/coding/variables.py in __array__(self, dtype)
#      68
#      69     def __array__(self, dtype=None):
# ---> 70         return self.func(self.array)
#      71
#      72     def __repr__(self):
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/coding/variables.py in _apply_mask(data, encoded_fill_values, decoded_fill_value, dtype)
#     135 ) -> np.ndarray:
#     136     """Mask all matching values in a NumPy arrays."""
# --> 137     data = np.asarray(data, dtype=dtype)
#     138     condition = False
#     139     for fv in encoded_fill_values:
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     417     def __array__(self, dtype=None):
#     418         array = as_indexable(self.array)
# --> 419         return np.asarray(array[self.key], dtype=None)
#     420
#     421     def transpose(self, order):
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/backends/zarr.py in __getitem__(self, key)
#      73         array = self.get_array()
#      74         if isinstance(key, indexing.BasicIndexer):
# ---> 75             return array[key.tuple]
#      76         elif isinstance(key, indexing.VectorizedIndexer):
#      77             return array.vindex[
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in __getitem__(self, selection)
#     660
#     661         fields, selection = pop_fields(selection)
# --> 662         return self.get_basic_selection(selection, fields=fields)
#     663
#     664     def get_basic_selection(self, selection=Ellipsis, out=None, fields=None):
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in get_basic_selection(self, selection, out, fields)
#     785                                                 fields=fields)
#     786         else:
# --> 787             return self._get_basic_selection_nd(selection=selection, out=out,
#     788                                                 fields=fields)
#     789
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _get_basic_selection_nd(self, selection, out, fields)
#     828         indexer = BasicIndexer(selection, self)
#     829
# --> 830         return self._get_selection(indexer=indexer, out=out, fields=fields)
#     831
#     832     def get_orthogonal_selection(self, selection, out=None, fields=None):
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _get_selection(self, indexer, out, fields)
#    1123             # allow storage to get multiple items at once
#    1124             lchunk_coords, lchunk_selection, lout_selection = zip(*indexer)
# -> 1125             self._chunk_getitems(lchunk_coords, lchunk_selection, out, lout_selection,
#    1126                                  drop_axes=indexer.drop_axes, fields=fields)
#    1127
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _chunk_getitems(self, lchunk_coords, lchunk_selection, out, lout_selection, drop_axes, fields)
#    1837         for ckey, chunk_select, out_select in zip(ckeys, lchunk_selection, lout_selection):
#    1838             if ckey in cdatas:
# -> 1839                 self._process_chunk(
#    1840                     out,
#    1841                     cdatas[ckey],
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _process_chunk(self, out, cdata, chunk_selection, drop_axes, out_is_ndarray, fields, out_selection, partial_read_decode)
#    1743         except ArrayIndexError:
#    1744             cdata = cdata.read_full()
# -> 1745         chunk = self._decode_chunk(cdata)
#    1746
#    1747         # select data from chunk
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _decode_chunk(self, cdata, start, nitems, expected_shape)
#    1976         if self._filters:
#    1977             for f in reversed(self._filters):
# -> 1978                 chunk = f.decode(chunk)
#    1979
#    1980         # view as numpy array with correct dtype
#
# ~/miniconda3/lib/python3.9/site-packages/numcodecs/shuffle.py in decode(self, buf, out)
#      48
#      49     def decode(self, buf, out=None):
# ---> 50         buf, out = self._prepare_arrays(buf, out)
#      51
#      52         if self.elementsize <= 1:
#
# ~/miniconda3/lib/python3.9/site-packages/numcodecs/shuffle.py in _prepare_arrays(self, buf, out)
#      33
#      34         if buf.nbytes % self.elementsize != 0:
# ---> 35             raise ValueError("Shuffle buffer is not an integer multiple of elementsize")
#      36
#      37         return buf, out
#
# ValueError: Shuffle buffer is not an integer multiple of elementsize

# %%
mur_hawaii
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 173, lat: 501, lon: 601)
# Coordinates:
#   * lat           (lat) float32 18.0 18.01 18.02 18.03 ... 22.98 22.99 23.0
#   * lon           (lon) float32 -160.0 -160.0 -160.0 ... -154.0 -154.0 -154.0
#   * time          (time) datetime64[ns] 2019-08-01T09:00:00 ... 2020-01-20T09...
# Data variables:
#     analysed_sst  (time, lat, lon) float32 dask.array<chunksize=(30, 100, 100), meta=np.ndarray>
#     mask          (time, lat, lon) float32 dask.array<chunksize=(30, 100, 100), meta=np.ndarray>
# Attributes: (12/47)
#     Conventions:                CF-1.7
#     title:                      Daily MUR SST, Final product
#     summary:                    A merged, multi-sensor L4 Foundation SST anal...
#     references:                 http://podaac.jpl.nasa.gov/Multi-scale_Ultra-...
#     institution:                Jet Propulsion Laboratory
#     history:                    created at nominal 4-day latency; replaced nr...
#     ...                         ...
#     project:                    NASA Making Earth Science Data Records for Us...
#     publisher_name:             GHRSST Project Office
#     publisher_url:              http://www.ghrsst.org
#     publisher_email:            ghrsst-po@nceo.ac.uk
#     processing_level:           L4
#     cdm_data_type:              grid

# %% [markdown]
# ### Add in NAN Values for Land to MUR Data
# <br/>
# We use the mask dimension to replace temperature values from land observations with NaN so that they are not factored in to our calculations. The mask variable has a value for each coordinate pair representing which surface the temperature was collected from (land, open-sea, ice, etc.).

# %%
mur_hawaii_sst = mur_hawaii['analysed_sst'].where(mur_hawaii.mask == 1)

# %% [markdown]
# ### Convert Temperatures to Celsius
# <br/>
# The dataset is stored with temperatures measured in Kelvin. This converts it to Celsius for ease of understanding and analysis.

# %%
mur_hawaii_sst = mur_hawaii_sst - 273.15

# %%
mur_hawaii_sst
# Out:
# <xarray.DataArray 'analysed_sst' (time: 173, lat: 501, lon: 601)>
# dask.array<sub, shape=(173, 501, 601), dtype=float32, chunksize=(30, 100, 100), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float32 18.0 18.01 18.02 18.03 ... 22.97 22.98 22.99 23.0
#   * lon      (lon) float32 -160.0 -160.0 -160.0 -160.0 ... -154.0 -154.0 -154.0
#   * time     (time) datetime64[ns] 2019-08-01T09:00:00 ... 2020-01-20T09:00:00

# %% [markdown]
# ### Open MUR Climatology for Hawaii

# %%
mur_clim = xr.open_dataarray(
    "../data/MURClimatology.nc",
    chunks={"time": 30, "lat": 100, "lon": 100}
)

# %%
mur_clim
# Out:
# <xarray.DataArray 'sstclim' (time: 366, lat: 501, lon: 601)>
# dask.array<open_dataset-837d8d05a1d81c5a93886d4de6004f45sstclim, shape=(366, 501, 601), dtype=float32, chunksize=(30, 100, 100), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float32 -160.0 -160.0 -160.0 -160.0 ... -154.0 -154.0 -154.0
#   * lat      (lat) float32 18.0 18.01 18.02 18.03 ... 22.97 22.98 22.99 23.0
#   * time     (time) datetime64[ns] 2004-01-01T09:00:00 ... 2004-12-31T09:00:00
# Attributes:
#     description:  Hawaii Climatology from 2002-2015.
#     start_date:   01/01
#     end_date:     12/31
#     units:        degC

# %% [markdown]
# ### Drop the Leap Day

# %%
mur_clim = mur_clim.where(mur_clim["time"] != np.datetime64('2004-02-29T09:00:00', 'ns'), drop=True)

# %% [markdown]
# ### Create Subset Dataset

# %%
mur_clim_jan = mur_clim[0:20]

# %%
mur_clim_subset = mur_clim[212:]

# %%
mur_clim_subset = xr.concat([mur_clim_subset, mur_clim_jan], dim="time")

# %%
mur_clim_subset = mur_clim_subset.assign_coords({"time": mur_hawaii_sst["time"]})

# %%
mur_clim_subset
# Out:
# <xarray.DataArray 'sstclim' (time: 173, lat: 501, lon: 601)>
# dask.array<concatenate, shape=(173, 501, 601), dtype=float32, chunksize=(30, 100, 100), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float32 -160.0 -160.0 -160.0 -160.0 ... -154.0 -154.0 -154.0
#   * lat      (lat) float32 18.0 18.01 18.02 18.03 ... 22.97 22.98 22.99 23.0
#   * time     (time) datetime64[ns] 2019-08-01T09:00:00 ... 2020-01-20T09:00:00
# Attributes:
#     description:  Hawaii Climatology from 2002-2015.
#     start_date:   01/01
#     end_date:     12/31
#     units:        degC

# %% [markdown]
# ### Create SST Anomaly Dataset

# %%
sst_anomaly = mur_hawaii_sst - mur_clim_subset

# %%
sst_anomaly
# Out:
# <xarray.DataArray (time: 173, lat: 501, lon: 601)>
# dask.array<sub, shape=(173, 501, 601), dtype=float32, chunksize=(27, 100, 100), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float32 18.0 18.01 18.02 18.03 ... 22.97 22.98 22.99 23.0
#   * lon      (lon) float32 -160.0 -160.0 -160.0 -160.0 ... -154.0 -154.0 -154.0
#   * time     (time) datetime64[ns] 2019-08-01T09:00:00 ... 2020-01-20T09:00:00

# %% [markdown]
# ### Find Daily Average SST Anomaly for Time Series

# %%
sst_anomaly_mean_ts = sst_anomaly.mean(['lat', 'lon'])

# %%
sst_anomaly_mean_ts
# Out:
# <xarray.DataArray (time: 173)>
# dask.array<mean_agg-aggregate, shape=(173,), dtype=float32, chunksize=(27,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2019-08-01T09:00:00 ... 2020-01-20T09:00:00

# %% [markdown]
# ### Find Average SST Anomaly for Each Coordinate Pair for Spatial Plot

# %%
sst_anomaly_mean_sp = sst_anomaly.mean(['time'])

# %%
sst_anomaly_mean_sp
# Out:
# <xarray.DataArray (lat: 501, lon: 601)>
# dask.array<mean_agg-aggregate, shape=(501, 601), dtype=float32, chunksize=(100, 100), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float32 18.0 18.01 18.02 18.03 ... 22.97 22.98 22.99 23.0
#   * lon      (lon) float32 -160.0 -160.0 -160.0 -160.0 ... -154.0 -154.0 -154.0

# %% [markdown]
# ## Regional Tests

# %% [markdown]
# ### Regional SST Anomaly Averaged Time Series, August 1st, 2019 - January 20th, 2020

# %%
start_time = timeit.default_timer()

sst_anomaly_mean_ts.plot()

elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-21e2691d23d5> in <module>
#       1 start_time = timeit.default_timer()
#       2
# ----> 3 sst_anomaly_mean_ts.plot()
#       4
#       5 elapsed = timeit.default_timer() - start_time
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/plot/plot.py in __call__(self, **kwargs)
#     864
#     865     def __call__(self, **kwargs):
# --> 866         return plot(self._da, **kwargs)
#     867
#     868     # we can't use functools.wraps here since that also modifies the name / qualname
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/plot/plot.py in plot(darray, row, col, col_wrap, ax, hue, rtol, subplot_kws, **kwargs)
#     293     xarray.DataArray.squeeze
#     294     """
# --> 295     darray = darray.squeeze().compute()
#     296
#     297     plot_dims = set(darray.dims)
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/dataarray.py in compute(self, **kwargs)
#     953         """
#     954         new = self.copy(deep=False)
# --> 955         return new.load(**kwargs)
#     956
#     957     def persist(self, **kwargs) -> "DataArray":
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/dataarray.py in load(self, **kwargs)
#     927         dask.compute
#     928         """
# --> 929         ds = self._to_temp_dataset().load(**kwargs)
#     930         new = self._from_temp_dataset(ds)
#     931         self._variable = new._variable
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/dataset.py in load(self, **kwargs)
#     863
#     864             # evaluate all the dask arrays simultaneously
# --> 865             evaluated_data = da.compute(*lazy_data.values(), **kwargs)
#     866
#     867             for k, data in zip(lazy_data, evaluated_data):
#
# ~/miniconda3/lib/python3.9/site-packages/dask/base.py in compute(*args, **kwargs)
#     566         postcomputes.append(x.__dask_postcompute__())
#     567
# --> 568     results = schedule(dsk, keys, **kwargs)
#     569     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     570
#
# ~/miniconda3/lib/python3.9/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      77             pool = MultiprocessingPoolExecutor(pool)
#      78
# ---> 79     results = get_async(
#      80         pool.submit,
#      81         pool._max_workers,
#
# ~/miniconda3/lib/python3.9/site-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     512                             _execute_task(task, data)  # Re-execute locally
#     513                         else:
# --> 514                             raise_exception(exc, tb)
#     515                     res, worker_id = loads(res_info)
#     516                     state["cache"][key] = res
#
# ~/miniconda3/lib/python3.9/site-packages/dask/local.py in reraise(exc, tb)
#     323     if exc.__traceback__ is not tb:
#     324         raise exc.with_traceback(tb)
# --> 325     raise exc
#     326
#     327
#
# ~/miniconda3/lib/python3.9/site-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     221     try:
#     222         task, data = loads(task_info)
# --> 223         result = _execute_task(task, data)
#     224         id = get_id()
#     225         result = dumps((result, id))
#
# ~/miniconda3/lib/python3.9/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~/miniconda3/lib/python3.9/site-packages/dask/array/core.py in getter(a, b, asarray, lock)
#     102         # `is_arraylike` evaluates to `True` in that case.
#     103         if asarray and (not is_arraylike(c) or isinstance(c, np.matrix)):
# --> 104             c = np.asarray(c)
#     105     finally:
#     106         if lock:
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     352
#     353     def __array__(self, dtype=None):
# --> 354         return np.asarray(self.array, dtype=dtype)
#     355
#     356     def __getitem__(self, key):
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     516
#     517     def __array__(self, dtype=None):
# --> 518         return np.asarray(self.array, dtype=dtype)
#     519
#     520     def __getitem__(self, key):
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     417     def __array__(self, dtype=None):
#     418         array = as_indexable(self.array)
# --> 419         return np.asarray(array[self.key], dtype=None)
#     420
#     421     def transpose(self, order):
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/coding/variables.py in __array__(self, dtype)
#      68
#      69     def __array__(self, dtype=None):
# ---> 70         return self.func(self.array)
#      71
#      72     def __repr__(self):
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/coding/variables.py in _apply_mask(data, encoded_fill_values, decoded_fill_value, dtype)
#     135 ) -> np.ndarray:
#     136     """Mask all matching values in a NumPy arrays."""
# --> 137     data = np.asarray(data, dtype=dtype)
#     138     condition = False
#     139     for fv in encoded_fill_values:
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     417     def __array__(self, dtype=None):
#     418         array = as_indexable(self.array)
# --> 419         return np.asarray(array[self.key], dtype=None)
#     420
#     421     def transpose(self, order):
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/backends/zarr.py in __getitem__(self, key)
#      73         array = self.get_array()
#      74         if isinstance(key, indexing.BasicIndexer):
# ---> 75             return array[key.tuple]
#      76         elif isinstance(key, indexing.VectorizedIndexer):
#      77             return array.vindex[
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in __getitem__(self, selection)
#     660
#     661         fields, selection = pop_fields(selection)
# --> 662         return self.get_basic_selection(selection, fields=fields)
#     663
#     664     def get_basic_selection(self, selection=Ellipsis, out=None, fields=None):
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in get_basic_selection(self, selection, out, fields)
#     785                                                 fields=fields)
#     786         else:
# --> 787             return self._get_basic_selection_nd(selection=selection, out=out,
#     788                                                 fields=fields)
#     789
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _get_basic_selection_nd(self, selection, out, fields)
#     828         indexer = BasicIndexer(selection, self)
#     829
# --> 830         return self._get_selection(indexer=indexer, out=out, fields=fields)
#     831
#     832     def get_orthogonal_selection(self, selection, out=None, fields=None):
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _get_selection(self, indexer, out, fields)
#    1123             # allow storage to get multiple items at once
#    1124             lchunk_coords, lchunk_selection, lout_selection = zip(*indexer)
# -> 1125             self._chunk_getitems(lchunk_coords, lchunk_selection, out, lout_selection,
#    1126                                  drop_axes=indexer.drop_axes, fields=fields)
#    1127
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _chunk_getitems(self, lchunk_coords, lchunk_selection, out, lout_selection, drop_axes, fields)
#    1837         for ckey, chunk_select, out_select in zip(ckeys, lchunk_selection, lout_selection):
#    1838             if ckey in cdatas:
# -> 1839                 self._process_chunk(
#    1840                     out,
#    1841                     cdatas[ckey],
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _process_chunk(self, out, cdata, chunk_selection, drop_axes, out_is_ndarray, fields, out_selection, partial_read_decode)
#    1743         except ArrayIndexError:
#    1744             cdata = cdata.read_full()
# -> 1745         chunk = self._decode_chunk(cdata)
#    1746
#    1747         # select data from chunk
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _decode_chunk(self, cdata, start, nitems, expected_shape)
#    1976         if self._filters:
#    1977             for f in reversed(self._filters):
# -> 1978                 chunk = f.decode(chunk)
#    1979
#    1980         # view as numpy array with correct dtype
#
# ~/miniconda3/lib/python3.9/site-packages/numcodecs/shuffle.py in decode(self, buf, out)
#      48
#      49     def decode(self, buf, out=None):
# ---> 50         buf, out = self._prepare_arrays(buf, out)
#      51
#      52         if self.elementsize <= 1:
#
# ~/miniconda3/lib/python3.9/site-packages/numcodecs/shuffle.py in _prepare_arrays(self, buf, out)
#      33
#      34         if buf.nbytes % self.elementsize != 0:
# ---> 35             raise ValueError("Shuffle buffer is not an integer multiple of elementsize")
#      36
#      37         return buf, out
#
# ValueError: Shuffle buffer is not an integer multiple of elementsize

# %% [markdown]
# ### Regional SST Anomaly Averaged Spatial Plot, August 1st, 2019 - January 20th, 2020

# %%
start_time = timeit.default_timer()

sst_anomaly_mean_sp.plot()

elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-04b9e466498e> in <module>
#       1 start_time = timeit.default_timer()
#       2
# ----> 3 sst_anomaly_mean_sp.plot()
#       4
#       5 elapsed = timeit.default_timer() - start_time
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/plot/plot.py in __call__(self, **kwargs)
#     864
#     865     def __call__(self, **kwargs):
# --> 866         return plot(self._da, **kwargs)
#     867
#     868     # we can't use functools.wraps here since that also modifies the name / qualname
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/plot/plot.py in plot(darray, row, col, col_wrap, ax, hue, rtol, subplot_kws, **kwargs)
#     293     xarray.DataArray.squeeze
#     294     """
# --> 295     darray = darray.squeeze().compute()
#     296
#     297     plot_dims = set(darray.dims)
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/dataarray.py in compute(self, **kwargs)
#     953         """
#     954         new = self.copy(deep=False)
# --> 955         return new.load(**kwargs)
#     956
#     957     def persist(self, **kwargs) -> "DataArray":
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/dataarray.py in load(self, **kwargs)
#     927         dask.compute
#     928         """
# --> 929         ds = self._to_temp_dataset().load(**kwargs)
#     930         new = self._from_temp_dataset(ds)
#     931         self._variable = new._variable
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/dataset.py in load(self, **kwargs)
#     863
#     864             # evaluate all the dask arrays simultaneously
# --> 865             evaluated_data = da.compute(*lazy_data.values(), **kwargs)
#     866
#     867             for k, data in zip(lazy_data, evaluated_data):
#
# ~/miniconda3/lib/python3.9/site-packages/dask/base.py in compute(*args, **kwargs)
#     566         postcomputes.append(x.__dask_postcompute__())
#     567
# --> 568     results = schedule(dsk, keys, **kwargs)
#     569     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     570
#
# ~/miniconda3/lib/python3.9/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      77             pool = MultiprocessingPoolExecutor(pool)
#      78
# ---> 79     results = get_async(
#      80         pool.submit,
#      81         pool._max_workers,
#
# ~/miniconda3/lib/python3.9/site-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     512                             _execute_task(task, data)  # Re-execute locally
#     513                         else:
# --> 514                             raise_exception(exc, tb)
#     515                     res, worker_id = loads(res_info)
#     516                     state["cache"][key] = res
#
# ~/miniconda3/lib/python3.9/site-packages/dask/local.py in reraise(exc, tb)
#     323     if exc.__traceback__ is not tb:
#     324         raise exc.with_traceback(tb)
# --> 325     raise exc
#     326
#     327
#
# ~/miniconda3/lib/python3.9/site-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     221     try:
#     222         task, data = loads(task_info)
# --> 223         result = _execute_task(task, data)
#     224         id = get_id()
#     225         result = dumps((result, id))
#
# ~/miniconda3/lib/python3.9/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~/miniconda3/lib/python3.9/site-packages/dask/array/core.py in getter(a, b, asarray, lock)
#     102         # `is_arraylike` evaluates to `True` in that case.
#     103         if asarray and (not is_arraylike(c) or isinstance(c, np.matrix)):
# --> 104             c = np.asarray(c)
#     105     finally:
#     106         if lock:
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     352
#     353     def __array__(self, dtype=None):
# --> 354         return np.asarray(self.array, dtype=dtype)
#     355
#     356     def __getitem__(self, key):
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     516
#     517     def __array__(self, dtype=None):
# --> 518         return np.asarray(self.array, dtype=dtype)
#     519
#     520     def __getitem__(self, key):
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     417     def __array__(self, dtype=None):
#     418         array = as_indexable(self.array)
# --> 419         return np.asarray(array[self.key], dtype=None)
#     420
#     421     def transpose(self, order):
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/coding/variables.py in __array__(self, dtype)
#      68
#      69     def __array__(self, dtype=None):
# ---> 70         return self.func(self.array)
#      71
#      72     def __repr__(self):
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/coding/variables.py in _apply_mask(data, encoded_fill_values, decoded_fill_value, dtype)
#     135 ) -> np.ndarray:
#     136     """Mask all matching values in a NumPy arrays."""
# --> 137     data = np.asarray(data, dtype=dtype)
#     138     condition = False
#     139     for fv in encoded_fill_values:
#
# ~/miniconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     417     def __array__(self, dtype=None):
#     418         array = as_indexable(self.array)
# --> 419         return np.asarray(array[self.key], dtype=None)
#     420
#     421     def transpose(self, order):
#
# ~/miniconda3/lib/python3.9/site-packages/xarray/backends/zarr.py in __getitem__(self, key)
#      73         array = self.get_array()
#      74         if isinstance(key, indexing.BasicIndexer):
# ---> 75             return array[key.tuple]
#      76         elif isinstance(key, indexing.VectorizedIndexer):
#      77             return array.vindex[
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in __getitem__(self, selection)
#     660
#     661         fields, selection = pop_fields(selection)
# --> 662         return self.get_basic_selection(selection, fields=fields)
#     663
#     664     def get_basic_selection(self, selection=Ellipsis, out=None, fields=None):
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in get_basic_selection(self, selection, out, fields)
#     785                                                 fields=fields)
#     786         else:
# --> 787             return self._get_basic_selection_nd(selection=selection, out=out,
#     788                                                 fields=fields)
#     789
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _get_basic_selection_nd(self, selection, out, fields)
#     828         indexer = BasicIndexer(selection, self)
#     829
# --> 830         return self._get_selection(indexer=indexer, out=out, fields=fields)
#     831
#     832     def get_orthogonal_selection(self, selection, out=None, fields=None):
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _get_selection(self, indexer, out, fields)
#    1123             # allow storage to get multiple items at once
#    1124             lchunk_coords, lchunk_selection, lout_selection = zip(*indexer)
# -> 1125             self._chunk_getitems(lchunk_coords, lchunk_selection, out, lout_selection,
#    1126                                  drop_axes=indexer.drop_axes, fields=fields)
#    1127
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _chunk_getitems(self, lchunk_coords, lchunk_selection, out, lout_selection, drop_axes, fields)
#    1837         for ckey, chunk_select, out_select in zip(ckeys, lchunk_selection, lout_selection):
#    1838             if ckey in cdatas:
# -> 1839                 self._process_chunk(
#    1840                     out,
#    1841                     cdatas[ckey],
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _process_chunk(self, out, cdata, chunk_selection, drop_axes, out_is_ndarray, fields, out_selection, partial_read_decode)
#    1743         except ArrayIndexError:
#    1744             cdata = cdata.read_full()
# -> 1745         chunk = self._decode_chunk(cdata)
#    1746
#    1747         # select data from chunk
#
# ~/miniconda3/lib/python3.9/site-packages/zarr/core.py in _decode_chunk(self, cdata, start, nitems, expected_shape)
#    1976         if self._filters:
#    1977             for f in reversed(self._filters):
# -> 1978                 chunk = f.decode(chunk)
#    1979
#    1980         # view as numpy array with correct dtype
#
# ~/miniconda3/lib/python3.9/site-packages/numcodecs/shuffle.py in decode(self, buf, out)
#      48
#      49     def decode(self, buf, out=None):
# ---> 50         buf, out = self._prepare_arrays(buf, out)
#      51
#      52         if self.elementsize <= 1:
#
# ~/miniconda3/lib/python3.9/site-packages/numcodecs/shuffle.py in _prepare_arrays(self, buf, out)
#      33
#      34         if buf.nbytes % self.elementsize != 0:
# ---> 35             raise ValueError("Shuffle buffer is not an integer multiple of elementsize")
#      36
#      37         return buf, out
#
# ValueError: Shuffle buffer is not an integer multiple of elementsize
