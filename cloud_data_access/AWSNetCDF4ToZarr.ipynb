# %% [markdown]
# # Converting NetCDF4 Data to Zarr

# %% [markdown]
# This notebook was developed following the workflow defined in Jack McNelis' "Use Case: Study Amazon Estuaries with Data from the EOSDIS Cloud" notebook, located here: https://github.com/podaac/tutorials/blob/master/notebooks/SWOT-EA-2021/Estuary_explore_inCloud_zarr.ipynb

# %% [markdown]
# **Goal**
# <br/>
# The goal of this notebook is to access the MUR 1-km SST dataset stored in the netCDF4 format, convert that data into Zarr using the Earthdata Harmony tool, and then run an analysis with a subset of that data.

# %% [markdown]
# **Dataset**
# <br/>
# MUR 1-km L4 SST (requires AWS early access in order to view on Earthdata Search) https://podaac.jpl.nasa.gov/MEaSUREs-MUR?tab=background&sections=about%2Bdata

# %% [markdown]
# ### Import Modules

# %%
import s3fs
import numpy as np
import xarray as xr
import fsspec
import zarr
import timeit
import time
import requests
import matplotlib.pyplot as plt
import pandas as pd
from dask.distributed import Client
from IPython.display import HTML
from json import dumps, loads
from platform import system
from netrc import netrc
from getpass import getpass
from urllib import request
from http.cookiejar import CookieJar
from os.path import join, expanduser

# %% [markdown]
# ### Period and Region of Interest

# %%
start_date = "2019-08-01"
end_date = "2020-1-20"

minlat = 18
maxlat = 23
minlon = -160
maxlon = -154

# %% [markdown]
# ### Set the CMR, URS, and Harmony Endpoints
# <br/>
# CMR, or the Earthdata Common Metadata Repository, is a high-performance, high-quality, continuously evolving metadata system that catalogs Earth Science data and associated service metadata records. URS is the Earthdata login system, that allows (free) download access to Earthdata data. Harmony API allows you to seamlessly analyze Earth observation data from different NASA data centers.

# %%
cmr = "cmr.earthdata.nasa.gov"
urs = "urs.earthdata.nasa.gov"
harmony = "harmony.earthdata.nasa.gov"

cmr, urs, harmony
# Out:
# ('cmr.earthdata.nasa.gov',
#  'urs.earthdata.nasa.gov',
#  'harmony.earthdata.nasa.gov')

# %% [markdown]
# ### Earthdata Login
# <br/>
# An Earthdata Login account is required to access data, as well as discover restricted data, from the NASA Earthdata system. Please visit https://urs.earthdata.nasa.gov to register and manage your Earthdata Login account. This account is free to create and only takes a moment to set up.
#
# The setup_earthdata_login_auth function will allow Python scripts to log into any Earthdata Login application programmatically. To avoid being prompted for credentials every time you run and also allow clients such as curl to log in, you can add the following to a .netrc (_netrc on Windows) file in your home directory:
#
#     machine urs.earthdata.nasa.gov
#     login <your username>
#     password <your password>
#
# Make sure that this file is only readable by the current user or you will receive an error stating "netrc access too permissive."
#
#     $ chmod 0600 ~/.netrc

# %%
TOKEN_DATA = ("<token>"
              "<username>%s</username>"
              "<password>%s</password>"
              "<client_id>PODAAC CMR Client</client_id>"
              "<user_ip_address>%s</user_ip_address>"
              "</token>")


def setup_earthdata_login_auth(urs: str='urs.earthdata.nasa.gov', cmr: str='cmr.earthdata.nasa.gov'):

    # GET URS LOGIN INFO FROM NETRC OR USER PROMPTS:
    netrc_name = "_netrc" if system()=="Windows" else ".netrc"
    try:
        username, _, password = netrc(file=join(expanduser('~'), netrc_name)).authenticators(urs)
        print("# Your URS credentials were securely retrieved from your .netrc file.")
    except (FileNotFoundError, TypeError):
        print('# Please provide your Earthdata Login credentials for access.')
        print('# Your info will only be passed to %s and will not be exposed in Jupyter.' % (urs))
        username = input('Username: ')
        password = getpass('Password: ')

    # SET UP URS AUTHENTICATION FOR HTTP DOWNLOADS:
    manager = request.HTTPPasswordMgrWithDefaultRealm()
    manager.add_password(None, urs, username, password)
    auth = request.HTTPBasicAuthHandler(manager)
    jar = CookieJar()
    processor = request.HTTPCookieProcessor(jar)
    opener = request.build_opener(auth, processor)
    request.install_opener(opener)

    # GET TOKEN TO ACCESS RESTRICTED CMR METADATA:
    ip = requests.get("https://ipinfo.io/ip").text.strip()
    r = requests.post(
        url="https://%s/legacy-services/rest/tokens" % cmr,
        data=TOKEN_DATA % (str(username), str(password), ip),
        headers={'Content-Type': 'application/xml', 'Accept': 'application/json'}
    )
    return r.json()['token']['id']


# Provide URS credentials for HTTP download auth & CMR token retrieval:
_token = setup_earthdata_login_auth(urs=urs, cmr=cmr)
# Out:
# # Your URS credentials were securely retrieved from your .netrc file.

# %% [markdown]
# ### Obtain Dataset Metadata

# %%
mur_ShortName = "MUR-JPL-L4-GLOB-v4.1"

# %%
r = requests.get(url=f"https://{cmr}/search/collections.umm_json", 
                 params={'provider': "POCLOUD", 
                         'ShortName': mur_ShortName, 
                         'token': _token})

mur_coll = r.json()
mur_coll_meta = mur_coll['items'][0]['meta']
mur_coll_meta
# Out:
# {'revision-id': 29,
#  'deleted': False,
#  'format': 'application/vnd.nasa.cmr.umm+json',
#  'provider-id': 'POCLOUD',
#  'user-id': 'mgangl',
#  'has-formats': False,
#  'associations': {'variables': ['V2028632042-POCLOUD',
#    'V2028632044-POCLOUD',
#    'V2028632047-POCLOUD',
#    'V2028668049-POCLOUD']},
#  's3-links': ['podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/',
#   'podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/'],
#  'has-spatial-subsetting': False,
#  'native-id': 'GHRSST+Level+4+MUR+Global+Foundation+Sea+Surface+Temperature+Analysis+(v4.1)',
#  'has-transforms': False,
#  'has-variables': True,
#  'concept-id': 'C1996881146-POCLOUD',
#  'revision-date': '2021-07-26T17:41:06.284Z',
#  'granule-count': 0,
#  'has-temporal-subsetting': False,
#  'concept-type': 'collection'}

# %% [markdown]
# ### Locate Granules
# <br/>
# You can see below that there are >7000 hits. Each hit represents a single day of data in the MUR SST dataset.

# %%
r = requests.get(url=f"https://{cmr}/search/granules.umm_json", 
                 params={'provider': "POCLOUD", 
                         'ShortName': mur_ShortName, 
                         'token': _token,
                         'page_size': 2000})

mur_gran = r.json()
mur_gran['hits']
# Out:
# 7018

# %%
mur_gran['items'][9]
# Out:
# {'meta': {'concept-type': 'granule',
#   'concept-id': 'G2028105753-POCLOUD',
#   'revision-id': 1,
#   'native-id': '20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#   'provider-id': 'POCLOUD',
#   'format': 'application/vnd.nasa.cmr.umm+json',
#   'revision-date': '2021-03-31T05:21:01.951Z'},
#  'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-10T21:00:00.000Z',
#     'BeginningDateTime': '2002-06-09T21:00:00.000Z'}},
#   'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#    'Name': 'UMM-G',
#    'Version': '1.6.3'},
#   'GranuleUR': '20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#   'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:20:32.509Z'},
#    {'Type': 'Update', 'Date': '2021-03-31T05:20:32.510Z'}],
#   'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#        'SouthBoundingCoordinate': -90,
#        'EastBoundingCoordinate': 180,
#        'NorthBoundingCoordinate': 90}]}}},
#   'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#      'Size': 327.50969791412354,
#      'Checksum': {'Value': '0627d795d9cced48039b39df23aa6622',
#       'Algorithm': 'MD5'},
#      'SizeInBytes': 343418809,
#      'Name': '20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'},
#     {'SizeUnit': 'MB',
#      'Size': 9.059906005859375e-05,
#      'Checksum': {'Value': 'c40a0dc8f735df4d1ea789eedb9cc2ea',
#       'Algorithm': 'MD5'},
#      'SizeInBytes': 95,
#      'Name': '20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'}],
#    'DayNightFlag': 'Unspecified',
#    'ProductionDateTime': '2015-08-19T10:00:23.000Z'},
#   'CollectionReference': {'Version': '4.1',
#    'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#   'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#     'Description': 'Download 20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#     'Type': 'EXTENDED METADATA'},
#    {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#     'Description': 'Download 20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#     'Type': 'GET DATA'},
#    {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#     'Description': 'Download 20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#     'Type': 'EXTENDED METADATA'},
#    {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#     'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#     'Type': 'VIEW RELATED INFORMATION'},
#    {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#     'Type': 'USE SERVICE API',
#     'Subtype': 'OPENDAP DATA',
#     'Description': 'OPeNDAP request URL'}]}}

# %%
mur_gran['items'][1999]
# Out:
# {'meta': {'concept-type': 'granule',
#   'concept-id': 'G2028143785-POCLOUD',
#   'revision-id': 1,
#   'native-id': '20071121090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#   'provider-id': 'POCLOUD',
#   'format': 'application/vnd.nasa.cmr.umm+json',
#   'revision-date': '2021-03-31T07:39:30.031Z'},
#  'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2007-11-21T21:00:00.000Z',
#     'BeginningDateTime': '2007-11-20T21:00:00.000Z'}},
#   'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#    'Name': 'UMM-G',
#    'Version': '1.6.3'},
#   'GranuleUR': '20071121090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#   'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T07:39:04.510Z'},
#    {'Type': 'Update', 'Date': '2021-03-31T07:39:04.510Z'}],
#   'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#        'SouthBoundingCoordinate': -90,
#        'EastBoundingCoordinate': 180,
#        'NorthBoundingCoordinate': 90}]}}},
#   'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#      'Size': 338.7899389266968,
#      'Checksum': {'Value': '79e89c4109e67539cbf2a5b6d7baf9b7',
#       'Algorithm': 'MD5'},
#      'SizeInBytes': 355246999,
#      'Name': '20071121090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'},
#     {'SizeUnit': 'MB',
#      'Size': 9.059906005859375e-05,
#      'Checksum': {'Value': '4bf84990d93083071e2cb1fba39683b0',
#       'Algorithm': 'MD5'},
#      'SizeInBytes': 95,
#      'Name': '20071121090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'}],
#    'DayNightFlag': 'Unspecified',
#    'ProductionDateTime': '2015-08-12T23:03:37.000Z'},
#   'CollectionReference': {'Version': '4.1',
#    'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#   'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20071121090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#     'Description': 'Download 20071121090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#     'Type': 'EXTENDED METADATA'},
#    {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20071121090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#     'Description': 'Download 20071121090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#     'Type': 'GET DATA'},
#    {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20071121090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#     'Description': 'Download 20071121090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#     'Type': 'EXTENDED METADATA'},
#    {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#     'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#     'Type': 'VIEW RELATED INFORMATION'},
#    {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20071121090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#     'Type': 'USE SERVICE API',
#     'Subtype': 'OPENDAP DATA',
#     'Description': 'OPeNDAP request URL'}]}}

# %% [markdown]
# The CMR Search metadata for a single day.

# %%
mur_gran['items'][0]['meta']
# Out:
# {'concept-type': 'granule',
#  'concept-id': 'G2030963432-POCLOUD',
#  'revision-id': 1,
#  'native-id': '20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#  'provider-id': 'POCLOUD',
#  'format': 'application/vnd.nasa.cmr.umm+json',
#  'revision-date': '2021-04-07T16:59:09.662Z'}

# %% [markdown]
# You can also obtain the UMM metadata, accessible from the 'umm' key.

# %%
mur_gran['items'][0]['umm']['RelatedUrls']
# Out:
# [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#   'Description': 'Download 20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#   'Type': 'GET DATA'},
#  {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#   'Description': 'Download 20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#   'Type': 'EXTENDED METADATA'},
#  {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#   'Description': 'Download 20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#   'Type': 'EXTENDED METADATA'},
#  {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#   'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#   'Type': 'VIEW RELATED INFORMATION'},
#  {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#   'Type': 'USE SERVICE API',
#   'Subtype': 'OPENDAP DATA',
#   'Description': 'OPeNDAP request URL'}]

# %% [markdown]
# We want the URL corresponding to 'Type': 'GET DATA'. Select the URL from appropriate item in the list, then print:

# %%
mur_gran['items']
# Out:
# [{'meta': {'concept-type': 'granule',
#    'concept-id': 'G2030963432-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-04-07T16:59:09.662Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-01T21:00:00.000Z',
#      'BeginningDateTime': '2002-05-31T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-04-07T16:58:43.887Z'},
#     {'Type': 'Update', 'Date': '2021-04-07T16:58:43.888Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': 'a22c9122476cf3f87eb880317aa54bfa',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'},
#      {'SizeUnit': 'MB',
#       'Size': 332.35974979400635,
#       'Checksum': {'Value': '2d8a33dfbfd3ed3c6885d0ac0f0df82b',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 348504457,
#       'Name': '20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T10:39:29.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028106835-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020602090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:22:10.258Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-02T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-01T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020602090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:21:40.855Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:21:40.856Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': '8c4e2a6aa8d9200e142c62809ba4916e',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020602090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'},
#      {'SizeUnit': 'MB',
#       'Size': 331.33482456207275,
#       'Checksum': {'Value': 'a2f3425d202888936610fe553a9a4edf',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 347429745,
#       'Name': '20020602090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T10:35:04.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020602090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020602090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020602090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020602090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020602090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020602090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020602090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028106890-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020603090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:22:53.919Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-03T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-02T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020603090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:22:25.358Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:22:25.358Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 329.771671295166,
#       'Checksum': {'Value': 'b1521b248624f5588adfb2177ae98984',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 345790660,
#       'Name': '20020603090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'},
#      {'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': 'e58460c34b1b17b4a93b5e0ff91ee191',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020603090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T10:30:42.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020603090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020603090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020603090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020603090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020603090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020603090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020603090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028106962-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020604090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:23:41.741Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-04T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-03T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020604090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:23:10.316Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:23:10.316Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 327.5539598464966,
#       'Checksum': {'Value': 'b4e40aa5946d1ae98b3e7443deb56a04',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 343465221,
#       'Name': '20020604090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'},
#      {'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': 'e9129b2e480e34d593b43543ae19760f',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020604090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T10:26:22.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020604090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020604090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020604090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020604090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020604090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020604090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020604090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028106862-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020605090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:22:30.840Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-05T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-04T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020605090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:21:56.096Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:21:56.096Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 318.64849376678467,
#       'Checksum': {'Value': '214c48f4f14d69ee1198e8f0f9d34903',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 334127163,
#       'Name': '20020605090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'},
#      {'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': '745853fcbf32a6f5f27057d046e9a813',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020605090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T10:21:59.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020605090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020605090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020605090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020605090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020605090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020605090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020605090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028105752-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020606090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:21:00.671Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-06T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-05T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020606090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:20:25.815Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:20:25.833Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': 'b7888f99f95ccdf3bf1db97f085f5b03',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020606090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'},
#      {'SizeUnit': 'MB',
#       'Size': 310.25645446777344,
#       'Checksum': {'Value': 'd809f793da0a5d08eeafd544b1f7b1eb',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 325327472,
#       'Name': '20020606090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T10:17:42.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020606090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020606090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020606090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020606090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020606090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020606090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020606090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028105744-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020607090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:20:56.282Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-07T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-06T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020607090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:20:30.728Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:20:30.728Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 316.9076223373413,
#       'Checksum': {'Value': '90974a08504c0a4f1b7fe15c91b7dd8b',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 332301727,
#       'Name': '20020607090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'},
#      {'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': 'fe93c9dd79fd271918dfc8a41f3657d7',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020607090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T10:13:25.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020607090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020607090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020607090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020607090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020607090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020607090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020607090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028106964-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020608090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:23:43.307Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-08T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-07T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020608090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:23:20.397Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:23:20.397Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': '850a6dbe674ea10caab53c3860e14285',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020608090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'},
#      {'SizeUnit': 'MB',
#       'Size': 327.881872177124,
#       'Checksum': {'Value': '4717228cdc074ecc4378be81a306c300',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 343809062,
#       'Name': '20020608090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T10:09:05.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020608090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020608090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020608090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020608090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020608090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020608090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020608090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028105698-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020609090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:20:20.962Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-09T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-08T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020609090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:19:48.205Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:19:48.205Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': '33f00d92f52e4710b355f103b254b116',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020609090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'},
#      {'SizeUnit': 'MB',
#       'Size': 328.56553649902344,
#       'Checksum': {'Value': '27fecbdb37ad562adf7e91e2253e54e1',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 344525936,
#       'Name': '20020609090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T10:04:43.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020609090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020609090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020609090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020609090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020609090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020609090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020609090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028105753-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:21:01.951Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-10T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-09T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:20:32.509Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:20:32.510Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 327.50969791412354,
#       'Checksum': {'Value': '0627d795d9cced48039b39df23aa6622',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 343418809,
#       'Name': '20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'},
#      {'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': 'c40a0dc8f735df4d1ea789eedb9cc2ea',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T10:00:23.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020610090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028105775-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020611090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:21:13.315Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-11T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-10T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020611090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:20:50.354Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:20:50.354Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': 'fe04e5d4c4c2389745fdd7f2738f95d0',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020611090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'},
#      {'SizeUnit': 'MB',
#       'Size': 326.52643299102783,
#       'Checksum': {'Value': '0d927e7d6312cdf86da2fbab911f7fe9',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 342387781,
#       'Name': '20020611090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T09:56:03.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020611090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020611090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020611090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020611090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020611090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020611090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020611090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028106814-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020612090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:21:56.369Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-12T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-11T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020612090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:21:30.045Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:21:30.045Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': 'a1e2557eca30922f1d6c8e33cfaf67f2',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020612090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'},
#      {'SizeUnit': 'MB',
#       'Size': 325.264199256897,
#       'Checksum': {'Value': 'd4b5bda081db0de8109825e1394950ec',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 341064233,
#       'Name': '20020612090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T09:51:43.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020612090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020612090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020612090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020612090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020612090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020612090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020612090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028105657-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020613090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:19:53.477Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-13T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-12T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020613090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:19:23.839Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:19:23.840Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': 'ae7a469e77c2bc15db39a1869f665698',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020613090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'},
#      {'SizeUnit': 'MB',
#       'Size': 325.2328824996948,
#       'Checksum': {'Value': '1c5377ff8f8b85ba89a38773adb28020',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 341031395,
#       'Name': '20020613090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T09:47:15.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020613090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020613090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020613090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020613090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020613090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020613090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020613090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028106848-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020614090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:22:18.850Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-14T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-13T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020614090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:21:52.395Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:21:52.395Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': 'a65f75dd02d7eec6cbbb9c63518c4196',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020614090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'},
#      {'SizeUnit': 'MB',
#       'Size': 324.20243072509766,
#       'Checksum': {'Value': 'd83a2ec6fbfcccec7f50fed340f49773',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 339950888,
#       'Name': '20020614090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T09:42:52.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020614090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020614090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020614090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20020614090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20020614090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20020614090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20020614090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028106994-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20020615090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T05:24:09.644Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2002-06-15T21:00:00.000Z',
#      'BeginningDateTime': '2002-06-14T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20020615090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T05:23:43.261Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T05:23:43.261Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 322.5335006713867,
#       'Checksum': {'Value': 'e138c44a51a3a39f3b8c69c7d658d4e5',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 338200888,
#       'Name': '20020615090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'},
#      {'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': '2536b699dadd7ed9d406ce53ea0742dd',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20020615090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-19T09:38:33.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020615090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20020615090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
# ...
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20050220090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T06:23:22.230Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T06:23:22.231Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 352.45727920532227,
#       'Checksum': {'Value': 'f668a2f8b5824e5e98807f7cace1c035',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 369578244,
#       'Name': '20050220090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'},
#      {'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': '34cd6d5fabdf45ec1f8fb7bcf02f81f3',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20050220090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-16T00:25:22.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20050220090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20050220090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20050220090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20050220090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20050220090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20050220090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20050220090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028123586-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20050221090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T06:22:46.201Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2005-02-21T21:00:00.000Z',
#      'BeginningDateTime': '2005-02-20T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20050221090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T06:22:23.549Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T06:22:23.551Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': '4f3b6b70791f57ab01a8cbf88f423a19',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20050221090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'},
#      {'SizeUnit': 'MB',
#       'Size': 354.3646764755249,
#       'Checksum': {'Value': '86ea59bb30005587cbac13039eefd1a2',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 371578295,
#       'Name': '20050221090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-16T00:20:57.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20050221090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20050221090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20050221090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20050221090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20050221090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20050221090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20050221090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028123743-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20050222090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T06:24:08.616Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2005-02-22T21:00:00.000Z',
#      'BeginningDateTime': '2005-02-21T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20050222090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T06:23:38.209Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T06:23:38.210Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 354.9970054626465,
#       'Checksum': {'Value': 'b2d6a1426666b6ae508eb29d803f8fb5',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 372241340,
#       'Name': '20050222090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'},
#      {'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': '429f5930e94df8a8876791b0197ffd68',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20050222090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-16T00:16:30.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20050222090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20050222090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20050222090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20050222090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20050222090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20050222090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20050222090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028123843-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20050223090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T06:25:00.166Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2005-02-23T21:00:00.000Z',
#      'BeginningDateTime': '2005-02-22T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20050223090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T06:24:38.095Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T06:24:38.096Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': 'df096a57be5e42b724bfb8b8bb79e133',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20050223090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'},
#      {'SizeUnit': 'MB',
#       'Size': 356.5481758117676,
#       'Checksum': {'Value': 'c2172997a436c98cd312c3790d9e909b',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 373867860,
#       'Name': '20050223090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-16T00:12:09.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20050223090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20050223090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20050223090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20050223090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20050223090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20050223090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20050223090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  {'meta': {'concept-type': 'granule',
#    'concept-id': 'G2028123867-POCLOUD',
#    'revision-id': 1,
#    'native-id': '20050224090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'provider-id': 'POCLOUD',
#    'format': 'application/vnd.nasa.cmr.umm+json',
#    'revision-date': '2021-03-31T06:25:10.006Z'},
#   'umm': {'TemporalExtent': {'RangeDateTime': {'EndingDateTime': '2005-02-24T21:00:00.000Z',
#      'BeginningDateTime': '2005-02-23T21:00:00.000Z'}},
#    'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.3',
#     'Name': 'UMM-G',
#     'Version': '1.6.3'},
#    'GranuleUR': '20050224090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#    'ProviderDates': [{'Type': 'Insert', 'Date': '2021-03-31T06:24:41.079Z'},
#     {'Type': 'Update', 'Date': '2021-03-31T06:24:41.080Z'}],
#    'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180,
#         'SouthBoundingCoordinate': -90,
#         'EastBoundingCoordinate': 180,
#         'NorthBoundingCoordinate': 90}]}}},
#    'DataGranule': {'ArchiveAndDistributionInformation': [{'SizeUnit': 'MB',
#       'Size': 9.059906005859375e-05,
#       'Checksum': {'Value': '1813d1c6cbf9a9bb6db3e70036bdad7f',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 95,
#       'Name': '20050224090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5'},
#      {'SizeUnit': 'MB',
#       'Size': 357.5091772079468,
#       'Checksum': {'Value': '62da5b203f989784644daa74388b1bb2',
#        'Algorithm': 'MD5'},
#       'SizeInBytes': 374875543,
#       'Name': '20050224090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'}],
#     'DayNightFlag': 'Unspecified',
#     'ProductionDateTime': '2015-08-16T00:07:45.000Z'},
#    'CollectionReference': {'Version': '4.1',
#     'ShortName': 'MUR-JPL-L4-GLOB-v4.1'},
#    'RelatedUrls': [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20050224090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Description': 'Download 20050224090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc',
#      'Type': 'GET DATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20050224090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Description': 'Download 20050224090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc.md5',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MUR-JPL-L4-GLOB-v4.1/20050224090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Description': 'Download 20050224090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.cmr.json',
#      'Type': 'EXTENDED METADATA'},
#     {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#      'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#      'Type': 'VIEW RELATED INFORMATION'},
#     {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%204%20MUR%20Global%20Foundation%20Sea%20Surface%20Temperature%20Analysis%20(v4.1)/granules/20050224090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1',
#      'Type': 'USE SERVICE API',
#      'Subtype': 'OPENDAP DATA',
#      'Description': 'OPeNDAP request URL'}]}},
#  ...]

# %%
mur_url = mur_gran['items'][0]['umm']['RelatedUrls'][0]['URL']
mur_url
# Out:
# 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MUR-JPL-L4-GLOB-v4.1/20020601090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.nc'

# %% [markdown]
# ### Request to Harmony API: Zarr Reformatter
# <br/>
# But we'll use the Harmony API's Zarr Reformatter service instead of downloading the entire granule. The zarr format will allow us to open and download/read just the data that we require for our Amazon Basin study area.
# <br/>
# <br/>
# If you have a jobID you'd like to re-visit instead of running this command again, modify the cell below to set the async_jobId then skip the one immediately after. You can continue from 'Query for the job status and links'.
# <br/>
# <br/>
# If you are running for the first time, proceed to the next cells to submit the harmony request.

# %%
async_jobId = "17086226-3ed5-4c5f-bc82-a56837623a01"  # jobId belongs to dev. You wont have access.
# async_jobId = None

# %% [markdown]
# See important usage note below if this is your first time submitting a request to the Zarr Reformatter service.
#
# The Zarr Reformatter service operates on an input Collection concept-id (a CMR construct). The service will accept more user-friendly inputs (like a Collection ShortName) in future releases. Here's how you identify the CMR concept-id for the JPL MUR 1-km SST dataset:

# %%
collection_concept_id = mur_coll_meta['concept-id']
collection_concept_id
# Out:
# 'C1996881146-POCLOUD'

# %%
lat = '(' + str(minlat) + ":" + str(maxlat) + ')'
lon = '(' + str(minlon) + ":" + str(maxlon) + ')' 
time = '(' + "\"" + '2019-08-01T09:00:00Z' + "\"" + ':' + "\"" + '2019-08-03T09:00:00Z' + "\"" + ')'

# %% [markdown]
# Most of this next cell will only evaluate if there's NOT a valid job identifier set to the async_jobId variable above. It submits the Harmony request, and prints the JSON response.
#
# **There is currently no Harmony L4 Subsetter service, so the following request will not be able to return a spatial subset of the MUR dataset (can be subset along time dimension, but not lat or lon). This request should work with an L2 dataset because there is a Harmony L2 Subsetter, and once there is a Harmony L4 Subsetter this request should also work.**

# %%
async_url = f'https://{harmony}/{collection_concept_id}/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?&subset=lat{lat}&subset=lon{lon}&subset=time{time}&format=application/x-zarr'
if async_jobId is None:
    print('Request URL: ', async_url)
    async_response = request.urlopen(async_url)
    async_results = async_response.read()
    async_json = loads(async_results)
    print(dumps(async_json, indent=2))
    async_jobId = async_json['jobID']

# %% [markdown]
# Format and display the complete url to the Harmony API job:

# %%
job_url = f'https://{harmony}/jobs/{async_jobId}'
job_url
# Out:
# 'https://harmony.earthdata.nasa.gov/jobs/17086226-3ed5-4c5f-bc82-a56837623a01'

# %% [markdown]
# Query for the job status and links in case the request is still processing:

# %%
while True:
    loop_response = request.urlopen(job_url)
    loop_results = loop_response.read()
    job_json = loads(loop_results)
    if job_json['status'] != 'running':
        break
    print(f"# Job status is running. Progress is {job_json['progress']}. Trying again.")
    time.sleep(5)

links = []
if job_json['status'] == 'successful' and job_json['progress'] == 100:
    print("# Job progress is 100%. Links to job outputs are displayed below:")
    links = [link['href'] for link in job_json['links']]
    display(links)
# Out:
# # Job progress is 100%. Links to job outputs are displayed below:
# ['https://harmony.earthdata.nasa.gov/stac/17086226-3ed5-4c5f-bc82-a56837623a01/',
#  'https://harmony.earthdata.nasa.gov/cloud-access.sh',
#  'https://harmony.earthdata.nasa.gov/cloud-access',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190801090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190802090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190803090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190804090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190805090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190806090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190807090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190808090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190809090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190810090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190811090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190812090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190813090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190814090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190815090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190816090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190817090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190818090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190819090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190820090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190821090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190822090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190823090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190824090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190825090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190826090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190827090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190828090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190829090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190830090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190831090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190901090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190902090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190903090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190904090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190905090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190906090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190907090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190908090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190909090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190910090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190911090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190912090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190913090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190914090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190915090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190916090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190917090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190918090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190919090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190920090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190921090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190922090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190923090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190924090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190925090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190926090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190927090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190928090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190929090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190930090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191001090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191002090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191003090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191004090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191005090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191006090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191007090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191008090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191009090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191010090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191011090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191012090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191013090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191014090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191015090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191016090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191017090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191018090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191019090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191020090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191021090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191022090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191023090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191024090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191025090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191026090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191027090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191028090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191029090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191030090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191031090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191101090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191102090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191103090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191104090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191105090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191106090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191107090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191108090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191109090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191110090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191111090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191112090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191113090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191114090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191115090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191116090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191117090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191118090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191119090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191120090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191121090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191122090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191123090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191124090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191125090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191126090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191127090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191128090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191129090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191130090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191201090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191202090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191203090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191204090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191205090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191206090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191207090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191208090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191209090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191210090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191211090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191212090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191213090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191214090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191215090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191216090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191217090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191218090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191219090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191220090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191221090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191222090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191223090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191224090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191225090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191226090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191227090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191228090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191229090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191230090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20191231090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200101090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200102090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200103090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200104090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200105090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200106090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200107090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200108090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200109090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200110090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200111090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200112090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200113090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200114090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200115090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200116090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200117090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200118090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200119090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20200120090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr',
#  'https://harmony.earthdata.nasa.gov/jobs/17086226-3ed5-4c5f-bc82-a56837623a01?page=1&limit=2000']

# %% [markdown]
# ### Access URL for the Output Zarr File
# <br/>
# The new zarr dataset/dataset is/are staged for us in an S3 bucket. The url ends in '.zarr' and for MUR begin at the 4th index in the list above. May be different with different datasets.
#
# Select the url and display below:

# %%
zarr_url = links[4]
zarr_url
# Out:
# 's3://harmony-prod-staging/public/harmony/netcdf-to-zarr/e78ccaad-04bd-4fe8-81c7-4d356e6ea1eb/20190801090000-JPL-L4_GHRSST-SSTfnd-MUR-GLOB-v02.0-fv04.1.zarr'

# %% [markdown]
# ### Access Credentials for the Output Zarr File
# <br/>
# Credentials provided at the third and fourth urls in the list grant authenticated access to your staged S3 resources.
#
# Grab the credentials as a JSON string, load to a Python dictionary, and display their expiration date:

# %%
with request.urlopen(f"https://{harmony}/cloud-access") as f:
    creds = loads(f.read())

creds['Expiration']
# Out:
# '2021-08-21T06:29:32.000Z'

# %% [markdown]
# ### Open Staged Zarr File with s3fs
# <br/>
# We use the AWS s3fs package to get metadata about the zarr data store and list its contents:
#
# (This shows a permission error becuase it is nearing the end of my internship and I believe my access has been revoked, however, this code should work)

# %%
zarr_fs = s3fs.S3FileSystem(
    key=creds['AccessKeyId'],
    secret=creds['SecretAccessKey'],
    token=creds['SessionToken'],
    client_kwargs={'region_name':'us-west-2'},
)
zarr_store = zarr_fs.get_mapper(root=zarr_url, check=False)
zarr_dataset = zarr.open(zarr_store)

print(zarr_dataset.tree())
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     245             try:
# --> 246                 out = await method(**additional_kwargs)
#     247                 return out
#
# ~/opt/anaconda3/lib/python3.8/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     153             error_class = self.exceptions.from_code(error_code)
# --> 154             raise error_class(parsed_response, operation_name)
#     155         else:
#
# ClientError: An error occurred (AccessDenied) when calling the ListObjectsV2 operation: Access Denied
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/s3fs/core.py in _info(self, path, bucket, key, refresh, version_id)
#    1056                     try:
# -> 1057                         out = await self._simple_info(path)
#    1058                     except PermissionError:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/s3fs/core.py in _simple_info(self, path)
#     969
# --> 970         out = await self._call_s3(
#     971             "list_objects_v2",
#
# ~/opt/anaconda3/lib/python3.8/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     264                 err = e
# --> 265         raise translate_boto_error(err)
#     266
#
# PermissionError: Access Denied
#
# During handling of the above exception, another exception occurred:
#
# ClientError                               Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     245             try:
# --> 246                 out = await method(**additional_kwargs)
#     247                 return out
#
# ~/opt/anaconda3/lib/python3.8/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     153             error_class = self.exceptions.from_code(error_code)
# --> 154             raise error_class(parsed_response, operation_name)
#     155         else:
#
# ClientError: An error occurred (403) when calling the HeadObject operation: Forbidden
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-26-0f5fea3445d1> in <module>
#       6 )
#       7 zarr_store = zarr_fs.get_mapper(root=zarr_url, check=False)
# ----> 8 zarr_dataset = zarr.open(zarr_store)
#       9
#      10 print(zarr_dataset.tree())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/zarr/convenience.py in open(store, mode, **kwargs)
#      87
#      88     elif mode == "a":
# ---> 89         if "shape" in kwargs or contains_array(store, path):
#      90             return open_array(store, mode=mode, **kwargs)
#      91         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/zarr/storage.py in contains_array(store, path)
#      94     prefix = _path_to_prefix(path)
#      95     key = prefix + array_meta_key
# ---> 96     return key in store
#      97
#      98
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fsspec/mapping.py in __contains__(self, key)
#     168         """Does key exist in mapping?"""
#     169         path = self._key_to_str(key)
# --> 170         return self.fs.exists(path) and self.fs.isfile(path)
#     171
#     172     def __reduce__(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fsspec/asyn.py in wrapper(*args, **kwargs)
#      85     def wrapper(*args, **kwargs):
#      86         self = obj or args[0]
# ---> 87         return sync(self.loop, func, *args, **kwargs)
#      88
#      89     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fsspec/asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      66         raise FSTimeoutError
#      67     if isinstance(result[0], BaseException):
# ---> 68         raise result[0]
#      69     return result[0]
#      70
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fsspec/asyn.py in _runner(event, coro, result, timeout)
#      22         coro = asyncio.wait_for(coro, timeout=timeout)
#      23     try:
# ---> 24         result[0] = await coro
#      25     except Exception as ex:
#      26         result[0] = ex
#
# ~/opt/anaconda3/lib/python3.8/site-packages/s3fs/core.py in _exists(self, path)
#     800                 return False
#     801             try:
# --> 802                 await self._info(path, bucket, key, version_id=version_id)
#     803                 return True
#     804             except FileNotFoundError:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/s3fs/core.py in _info(self, path, bucket, key, refresh, version_id)
#    1059                         # If the permissions aren't enough for scanning a prefix
#    1060                         # then fall back to using normal HEAD_OBJECT
# -> 1061                         out = await self._version_aware_info(path, version_id)
#    1062                 if out:
#    1063                     return out
#
# ~/opt/anaconda3/lib/python3.8/site-packages/s3fs/core.py in _version_aware_info(self, path, version_id)
#    1002
#    1003         try:
# -> 1004             out = await self._call_s3(
#    1005                 "head_object",
#    1006                 self.kwargs,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     263             except Exception as e:
#     264                 err = e
# --> 265         raise translate_boto_error(err)
#     266
#     267     call_s3 = sync_wrapper(_call_s3)
#
# PermissionError: Forbidden

# %%
print(zarr_dataset.analysed_sst.info)
# Out:
# Name               : /analysed_sst
# Type               : zarr.core.Array
# Data type          : float64
# Shape              : (1, 17999, 36000)
# Chunk shape        : (1, 1023, 2047)
# Order              : C
# Read-only          : False
# Compressor         : Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)
# Store type         : fsspec.mapping.FSMap
# No. bytes          : 5183712000 (4.8G)
# Chunks initialized : 324/324

# %% [markdown]
# ### Open Staged Zarr File with xarray

# %%
ds_MUR = xr.open_zarr(zarr_store)
print(ds_MUR)
# Out:
# <xarray.Dataset>
# Dimensions:           (time: 1, lat: 17999, lon: 36000)
# Coordinates:
#   * lon               (lon) float32 -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
#   * time              (time) datetime64[ns] 2019-08-01T09:00:00
# Dimensions without coordinates: lat
# Data variables:
#     analysed_sst      (time, lat, lon) float64 dask.array<chunksize=(1, 1023, 2047), meta=np.ndarray>
#     analysis_error    (time, lat, lon) float64 dask.array<chunksize=(1, 1023, 2047), meta=np.ndarray>
#     dt_1km_data       (time, lat, lon) timedelta64[ns] dask.array<chunksize=(1, 1447, 2895), meta=np.ndarray>
#     mask              (time, lat, lon) float32 dask.array<chunksize=(1, 1447, 2895), meta=np.ndarray>
#     sea_ice_fraction  (time, lat, lon) float64 dask.array<chunksize=(1, 1447, 2895), meta=np.ndarray>
#     sst_anomaly       (time, lat, lon) float64 dask.array<chunksize=(1, 1023, 2047), meta=np.ndarray>
# Attributes: (12/47)
#     Conventions:                CF-1.7
#     Metadata_Conventions:       Unidata Observation Dataset v1.0
#     acknowledgment:             Please acknowledge the use of these data with...
#     cdm_data_type:              grid
#     comment:                    MUR = "Multi-scale Ultra-high Resolution"
#     creator_email:              ghrsst@podaac.jpl.nasa.gov
#     ...                         ...
#     summary:                    A merged, multi-sensor L4 Foundation SST anal...
#     time_coverage_end:          20190801T210000Z
#     time_coverage_start:        20190731T210000Z
#     title:                      Daily MUR SST, Final product
#     uuid:                       27665bc0-d5fc-11e1-9b23-0800200c9a66
#     westernmost_longitude:      -180.0
