# %%
import numpy as np
import xarray as xr
import timeit
import matplotlib.pyplot as plt
from dask.distributed import Client

# %%
mur_clim = xr.open_dataarray(
    "../data/MURClimatology.nc", 
    chunks={"time": 30, "lat": 100, "lon": 100}
)

# %%
mur_clim
# Out:
# <xarray.DataArray 'sstclim' (time: 366, lat: 501, lon: 601)>
# dask.array<open_dataset-23b09ca0862f8b078b31539d678e451esstclim, shape=(366, 501, 601), dtype=float32, chunksize=(30, 100, 100), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float32 -160.0 -160.0 -160.0 -160.0 ... -154.0 -154.0 -154.0
#   * lat      (lat) float32 18.0 18.01 18.02 18.03 ... 22.97 22.98 22.99 23.0
#   * time     (time) datetime64[ns] 2004-01-01T09:00:00 ... 2004-12-31T09:00:00
# Attributes:
#     description:  Hawaii Climatology from 2002-2015.
#     start_date:   01/01
#     end_date:     12/31
#     units:        degC

# %%
mur_clim_mean = mur_clim.mean(['lat', 'lon'])

# %%
mur_clim_mean.plot()

# %%
mur_clim_mean[364].values
# Out:
# array(24.874569, dtype=float32)

# %%
mur_clim_mean[365].values
# Out:
# array(24.856739, dtype=float32)
